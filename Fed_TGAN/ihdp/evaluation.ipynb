# %%
import numpy as np
2+2
# Out:
# 4

# %%
def calc(result, L):
    true_ate= 3.98
    result = result[-L:]
    print('ATE',np.mean(result), 'Length', len(result))
    
    error= [abs(true_ate-result[i]) for i in range(len(result))]
    print('ATE error', np.mean(error), np.std(error))
    return np.mean(error), np.std(error)

# clients: 3 , samples: 50
# file_name= './save/ihdp_cur_3_50/ate_dict.pkl'
# file_name= './save/ihdp50again_3_50/ate_dict.pkl' #used right now.

#current
file_name= './save/ihdpcov_frommodel_3_50/ate_dict.pkl'    # ihdp
# file_name= './save/ihdp_v2_3_50/ate_dict.pkl'  # ihdp2
# file_name= './save/ihdp_shuffle1_3_50/ate_dict.pkl'   # ihdp3
# file_name= './save/ihdp_shuffle2_3_50/ate_dict.pkl'   # ihdps2



# file_name= './save/ihdp_cur_3_200/ate_dict.pkl'
# file_name= './save/ihdp_again_3_200/ate_dict.pkl'


# file_name= './save/ihdp_cur_12_50/ate_dict.pkl'

import pickle

# Load from pickle file
with open(file_name, "rb") as f:
    my_dict = pickle.load(f)

# print(my_dict[0])


L=20
ater=0
std=0
nc= len(my_dict.keys())
for key in my_dict:
    print(key)
    a, s= calc(my_dict[key], L)
    ater+=a
    std+=s
    
print('Final ate error', ater/nc)
print('Final std', std/nc)


# 0
# ATE 3.8643211687287775 Length 20
# ATE error 0.3082840650620784 0.26261319212402306
# 1
# ATE 3.086142990180961 Length 20
# ATE error 0.8938570098190391 0.3508310181411303
# 2
# ATE 4.094002880749845 Length 20
# ATE error 0.2911484072449707 0.24395441733519785
# Final ate error 0.4977631607086961
# Final std 0.2857995425334504



# 0
# ATE 3.8954366357458907 Length 20
# ATE error 0.2678695336823914 0.24170116281794968
# 1
# ATE 3.0795209467829805 Length 20
# ATE error 0.9004790532170197 0.3637685060039574
# 2
# ATE 4.123630459913598 Length 20
# ATE error 0.24725662395821119 0.22891400211134139
# Final ate error 0.4718684036192075
# Final std 0.2781278903110828


# 0
# ATE 3.631314947456449 Length 20
# ATE error 0.3853531686768843 0.28151535115505066
# 1
# ATE 3.4011351529550913 Length 20
# ATE error 0.7358252566823145 0.2519522038655952
# 2
# ATE 4.005969783031745 Length 20
# ATE error 0.22758407582761028 0.15920964561014583
# Final ate error 0.44958750039560297
# Final std 0.2308924002102639
# Out:
# 0
# ATE 3.741946771972432 Length 20
# ATE error 0.3728776197683983 0.2251041736329468
# 1
# ATE 3.6504507182843815 Length 20
# ATE error 0.34818475175884234 0.27614123467793555
# 2
# ATE 3.8669714796129306 Length 20
# ATE error 0.19679269722566672 0.1627890210386053
# Final ate error 0.30595168958430247
# Final std 0.22134480978316254

# %% [markdown]
# # Version 1: Result with client=3 samples_per_client=200

# %%
result= [3.3014623652945754, 3.498990578723434, 3.840431378220656, 4.310661498821162, 4.0449936419740276, 3.278536613018722, 4.024860753507149, 3.7128171856044565, 3.9436545394446285, 4.0268049924097475, 3.9194314501573126, 3.6696828375827515, 3.4211965560053095, 3.99749144719197, 3.983393569009052, 4.2714488499363235, 4.197463402370399, 3.2960914819067106, 3.714675427660454, 4.057018995606445, 4.187577092494541, 3.483310533287881, 2.806027301496015, 4.058223916968187, 3.9927778529644358, 3.6579203096956756, 3.7191122461733412, 3.8225740867010716, 4.261340864066494, 4.463737615250842, 4.473621912027559, 3.8410876929736144, 3.607533517899257, 4.795242482133947, 4.5951821494046, 4.243099247954884, 3.4254870956497863, 3.7538773016172535, 3.597830963298042, 4.413062296111316]

true_ate= 3.98
result = result[-20:]

